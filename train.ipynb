# %% [markdown]
# # Train Custom Model Using Scikit Learn

# %% [markdown]
# ## 1 Read in Collected Data and Process

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('coords.csv')

# %%
df.head()
# Out:
#   class        x1        y1        z1        v1        x2        y2        z2  \
# 0   ለምን  0.483307  0.231578 -0.584007  0.999898  0.504416  0.190950 -0.522643
# 1   ለምን  0.483975  0.231873 -0.666048  0.999945  0.506448  0.185909 -0.607750
# 2   ለምን  0.487058  0.233701 -0.761830  0.999960  0.509176  0.187470 -0.702055
# 3   ለምን  0.485298  0.236616 -0.635450  0.999879  0.509198  0.193196 -0.576642
# 4   ለምን  0.486986  0.238980 -0.642063  0.999903  0.510983  0.196924 -0.584852
#
#          v2        x3  ...       z39       x40       y40       z40       x41  \
# 0  0.999848  0.517840  ... -0.012437  0.316636  0.094683 -0.014839  0.329152
# 1  0.999922  0.518866  ... -0.012662  0.282908  0.103163 -0.014023  0.293204
# 2  0.999946  0.521292  ... -0.013867  0.266984  0.125805 -0.015711  0.279040
# 3  0.999811  0.521744  ... -0.013636  0.268645  0.147987 -0.014783  0.282323
# 4  0.999845  0.523073  ... -0.013496  0.272989  0.153211 -0.013506  0.287043
#
# ...

# %%
df.tail()
# Out:
#         class        x1        y1        z1        v1        x2        y2  \
# 11148  አውሮፕላን  0.589777  0.229622 -0.287269  0.999807  0.603178  0.198529
# 11149  አውሮፕላን  0.590050  0.238725 -0.355659  0.999758  0.604644  0.203386
# 11150  አውሮፕላን  0.588542  0.235149 -0.328806  0.999460  0.602914  0.200263
# 11151  አውሮፕላን  0.587551  0.235527 -0.313781  0.999547  0.601931  0.200939
# 11152  አውሮፕላን  0.584777  0.234899 -0.318611  0.999632  0.598695  0.200715
#
#              z2        v2        x3  ...       z39       x40       y40  \
# 11148 -0.253810  0.999442  0.612266  ... -0.011047  0.464943  0.180584
# 11149 -0.322612  0.999361  0.613431  ... -0.014089  0.453659  0.177954
# 11150 -0.295500  0.998721  0.611756  ... -0.014340  0.445705  0.181021
# 11151 -0.283246  0.998775  0.610818  ... -0.015133  0.445315  0.181067
# 11152 -0.288712  0.999006  0.607527  ... -0.014863  0.454346  0.185287
#
#             z40       x41       y41       z41       x42       y42       z42
# ...

# %%
df[df['class']=='nothing']
# Out:
#         class        x1        y1        z1        v1        x2        y2  \
# 4731  nothing  0.534317  0.242431 -0.699207  0.999438  0.547501  0.205316
# 4732  nothing  0.535507  0.242218 -0.715213  0.999467  0.548350  0.205084
# 4733  nothing  0.534615  0.243325 -0.719974  0.999533  0.547944  0.205250
# 4734  nothing  0.532304  0.242640 -0.668065  0.999543  0.546622  0.204689
# 4735  nothing  0.533055  0.243558 -0.649925  0.999579  0.547198  0.204944
# ...       ...       ...       ...       ...       ...       ...       ...
# 6350  nothing  0.406700  0.246025 -0.441741  0.997593  0.424983  0.210081
# 6351  nothing  0.407302  0.246400 -0.450969  0.998719  0.426468  0.210499
# 6352  nothing  0.409461  0.240212 -0.492297  0.999320  0.429849  0.205073
# 6353  nothing  0.411618  0.234806 -0.491361  0.999230  0.430682  0.199696
# 6354  nothing  0.411120  0.240197 -0.545659  0.999025  0.430271  0.205513
#
#             z2        v2        x3  ...  z39  x40  y40  z40  x41  y41  z41  \
# ...

# %%
X = df.drop('class', axis=1) # features
y = df['class'] # target value

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
y_test
# Out:
# 1093          ለምን
# 7463     መታጠቢያ ቤት
# 6573     መታጠቢያ ቤት
# 6677     መታጠቢያ ቤት
# 4398           ምን
#            ...
# 7352     መታጠቢያ ቤት
# 10948      አውሮፕላን
# 6225      nothing
# 2167           ምን
# 8232     መታጠቢያ ቤት
# Name: class, Length: 3346, dtype: object

# %% [markdown]
# ## 2 Train Machine Learning Classification Model

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipeline = make_pipeline(StandardScaler(), RandomForestClassifier(),verbose=True)

# %%
model = pipeline.fit(X_train, y_train)
# Out:
# [Pipeline] .... (step 1 of 2) Processing standardscaler, total=   0.0s

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model

# %%
fit_models
# Out:
# {'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
model.predict(X_test)
# Out:
# array(['መብላት', 'መብላት', 'መብላት', ..., 'ምን', 'nothing', 'ምን'], dtype=object)

# %% [markdown]
# ## 3 Evaluate and Serialize Model

# %%
import sklearn.metrics as metrics
import pickle

# %%
yhat = model.predict(X_test)

# %%
print(metrics.accuracy_score(y_test,yhat))
print(metrics.balanced_accuracy_score(y_test,yhat))
#print(metrics.recall_score(y_test,yhat,average="samples",labels=['ለምን','nothing','ምን','መቼ']))
# Out:
# 0.9962985811227637
# 0.9957402322786937

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['nothing', 'ምን', 'ለምን', ..., 'ለምን', 'ለምን', 'ምን'], dtype=object)

# %%
y_test
# Out:
# 5837    nothing
# 4709         ምን
# 363         ለምን
# 5916    nothing
# 3893         ምን
#          ...
# 548         ለምን
# 6240    nothing
# 165         ለምን
# 1043        ለምን
# 4501         ምን
# Name: class, Length: 1907, dtype: object

# %%
with open('ETHSLv2.pkl', 'wb') as f:
    pickle.dump(model, f)

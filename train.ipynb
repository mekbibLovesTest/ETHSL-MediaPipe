# 12084    የት  0.534007  0.256969 -0.492999  0.999997  0.546678  0.237555
#
#              z2        v2        x3  ...       z39       x40       y40  \
# 11917 -0.932584  0.999785  0.617555  ... -0.046919  0.418709  0.733896
# 11918 -1.060099  0.999815  0.621394  ... -0.043501  0.407288  0.724741
# 11919 -1.082000  0.999842  0.621085  ... -0.039020  0.408575  0.719246
# 11920 -0.413935  0.999997  0.602684  ... -0.013909  0.247903  0.768904
# 11921 -0.480090  0.999995  0.608296  ... -0.041613  0.298811  0.775641
# ...         ...       ...       ...  ...       ...       ...       ...
# 12080 -0.369693  0.999989  0.553319  ...  0.000000  0.000000  0.000000
# 12081 -0.324978  0.999995  0.552880  ... -0.009177  0.450267  0.565148
# 12082 -0.371443  0.999992  0.552492  ...  0.000000  0.000000  0.000000
# 12083 -0.447860  0.999994  0.554695  ... -0.003266  0.393467  0.546953
# 12084 -0.464415  0.999996  0.554474  ...  0.000000  0.000000  0.000000
#
#             z40       x41       y41       z41       x42       y42       z42
# 11917 -0.059171  0.432476  0.710305 -0.059906  0.445513  0.685696 -0.060845
# 11918 -0.056914  0.420618  0.696745 -0.059133  0.432238  0.669074 -0.060243
# 11919 -0.054279  0.421382  0.693466 -0.057664  0.432994  0.667653 -0.059029
# 11920 -0.020469  0.236868  0.776837 -0.022820  0.227166  0.787183 -0.024644
# 11921 -0.057490  0.294913  0.780603 -0.065251  0.290358  0.787454 -0.071049
# ...         ...       ...       ...       ...       ...       ...       ...
# 12080  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 12081 -0.010875  0.455993  0.566434 -0.011083  0.461179  0.567334 -0.011227
# 12082  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 12083 -0.004190  0.387347  0.544067 -0.003821  0.382063  0.541462 -0.003313
# 12084  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# [168 rows x 259 columns]

# %%
X = df.drop('class', axis=1) # features
y = df['class'] # target value

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
y_test
# Out:
# 3185           ምን
# 10534        መብላት
# 4448           ምን
# 7362     መታጠቢያ ቤት
# 11267     አመሰግናለሁ
#            ...
# 9697         መብላት
# 1794           ምን
# 3609           ምን
# 4792      nothing
# 3386           ምን
# Name: class, Length: 3626, dtype: object

# %% [markdown]
# ## 2 Train Machine Learning Classification Model

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipeline = make_pipeline(StandardScaler(), RandomForestClassifier(),verbose=True)

# %%
model = pipeline.fit(X_train, y_train)
# Out:
# [Pipeline] .... (step 1 of 2) Processing standardscaler, total=   0.1s
# [Pipeline]  (step 2 of 2) Processing randomforestclassifier, total=   5.9s

# %%
model.predict(X_test)
# Out:
# array(['ምን', 'መብላት', 'ምን', ..., 'ምን', 'nothing', 'ምን'], dtype=object)

# %% [markdown]
# ## 3 Evaluate and Serialize Model

# %%
import sklearn.metrics as metrics
import pickle

# %%
yhat = model.predict(X_test)

# %%
print(metrics.accuracy_score(y_test,yhat))
print(metrics.balanced_accuracy_score(y_test,yhat))
#print(metrics.recall_score(y_test,yhat,average="samples",labels=['ለምን','nothing','ምን','መቼ']))
# Out:
# 0.9931053502482073
# 0.9699873255192528

# %%
y_test
# Out:
# 3185           ምን
# 10534        መብላት
# 4448           ምን
# 7362     መታጠቢያ ቤት
# 11267     አመሰግናለሁ
#            ...
# 9697         መብላት
# 1794           ምን
# 3609           ምን
# 4792      nothing
# 3386           ምን
# Name: class, Length: 3626, dtype: object

# %%
with open('ETHSLv4.pkl', 'wb') as f:
    pickle.dump(model, f)
